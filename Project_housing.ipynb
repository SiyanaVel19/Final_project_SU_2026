# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Final project - The housing project

# %% [markdown]
# Currently I am a 2nd year economics and finance student and last semester I had a very interesting course called "Money, banking and financial markets".
# In this course we talked a lot about how interest rates affect the world and how it works as a tool to make people spend more or less, whatever is best for the economy.
# This was a very interesting notion to me and in this project I aim to analyze how different interest rates affect the housing prices around the world, in different economic areas - a growing problem around the world as it effect homelessness, economic stability etc

# %% [markdown]
# # The hypothesis I go into this project are the following:

# %% [markdown]
# H1: Interest rates affect housing prices equally across countries

# %% [markdown]
# H2: The affect of interest rates is stronger in high-income countries,than in low income countries

# %% [markdown]
# # The steps I aim to make for this project:

# %% [markdown]
# 1. Gather and clean data about: Housing prices, Interest rates, Income levels and Inflation
# 2. Clean and merge them into 1 big dataset
# 3. Divide countries into low, mid and high income;
# 4. Analyze trends per group over the years
# 5. Run a regression analysis on every group
# 6. Compare and Analyze - confirm or deny H1 AND H2
# 7. Summary of the project
